# %%
import polars as pl
import json

from pl_cleaning import *
from pl_embedding import *
from polars_etl.pl_duckdb_utils import *

# %%
df = pl.read_csv(r"C:\Users\samar\ai_ml_data_pipeline\data\input_data\tech_news.csv")

with open(r"C:\Users\samar\ai_ml_data_pipeline\data\input_data\company_metadata.json") as f:
    metadata =json.load(f)

metadata = pl.from_dicts(
    [{"company_name": k, **v} for k, v in metadata.items()]
)

# %%
df = df.with_columns([
    pl.col("revenue").map_elements(clean_revenue).alias("revenue_usd"),
    pl.col("published_date").map_elements(normalize_date).alias("published_date"),
    pl.col("category").map_elements(standardize_category).alias("category"),
])

# %%
df = df.with_columns([
    pl.col("published_date").dt.year().alias("year"),
    pl.col("published_date").dt.month().alias("month"),
    pl.col("published_date").dt.quarter().alias("quarter"),
])
# Out:
# ---------------------------------------------------------------------------
# InvalidOperationError                     Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df = df.with_columns([
#       2     pl.col("published_date").dt.year().alias("year"),
#       3     pl.col("published_date").dt.month().alias("month"),
#       4     pl.col("published_date").dt.quarter().alias("quarter"),
#       5 ])
#
# File c:\Users\samar\ai_ml_data_pipeline\venv\Lib\site-packages\polars\dataframe\frame.py:10507, in DataFrame.with_columns(self, *exprs, **named_exprs)
#   10380 """
#   10381 Add columns to this DataFrame.
#   10382
#    (...)  10500 └─────┴──────┴───────┴──────┴───────┘
#   10501 """
#   10502 from polars.lazyframe.opt_flags import QueryOptFlags
#   10504 return (
#   10505     self.lazy()
#   10506     .with_columns(*exprs, **named_exprs)
# > 10507     .collect(optimizations=QueryOptFlags._eager())
#   10508 )
#
# File c:\Users\samar\ai_ml_data_pipeline\venv\Lib\site-packages\polars\_utils\deprecation.py:97, in deprecate_streaming_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#      93         kwargs["engine"] = "in-memory"
#      95     del kwargs["streaming"]
# ---> 97 return function(*args, **kwargs)
#
# File c:\Users\samar\ai_ml_data_pipeline\venv\Lib\site-packages\polars\lazyframe\opt_flags.py:326, in forward_old_opt_flags.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     323         optflags = cb(optflags, kwargs.pop(key))  # type: ignore[no-untyped-call,unused-ignore]
#     325 kwargs["optimizations"] = optflags
# --> 326 return function(*args, **kwargs)
#
# File c:\Users\samar\ai_ml_data_pipeline\venv\Lib\site-packages\polars\lazyframe\frame.py:2464, in LazyFrame.collect(self, type_coercion, predicate_pushdown, projection_pushdown, simplify_expression, slice_pushdown, comm_subplan_elim, comm_subexpr_elim, cluster_with_columns, collapse_joins, no_optimization, engine, background, optimizations, **_kwargs)
#    2462 # Only for testing purposes
#    2463 callback = _kwargs.get("post_opt_callback", callback)
# -> 2464 return wrap_df(ldf.collect(engine, callback))
#
# InvalidOperationError: `year` operation not supported for dtype `null`
#
# This error occurred in the following expression:
# 	col("published_date").dt.year()
